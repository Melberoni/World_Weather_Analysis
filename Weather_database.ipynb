# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# Import linregress
from scipy.stats import linregress
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
#import the API key
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
import time

# %%
# Create a set of random latitude and longitude combinations.
lats= np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs=np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs=zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
   # if the city is unique then we will add it to the cities list
    if city not in cities:
        cities.append(city)
 #   print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid="+weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through all the cities in our list
for i, city in enumerate(cities):
    
    #group cities in set s of 50 for logging purposes
    if(i % 50==0 and i>=50):
        set_count+=1
        record_count=1
        time.sleep(60)
        
    #create endpoint url with each city
    city_url=url+"&q="+city.replace(" ","+")
    
    
    #log the url, record and set numbers and the city
    print(f"Processing Record {record_count} of set {set_count} | {city}")
    
   # add 1 to the record count
    record_count+=1
    
    try:
        #parse the JSON and retrieve data
        city_weather=requests.get(city_url).json()
        #parse out the needed data
        city_lat=city_weather["coord"]["lat"]
        city_lng=city_weather["coord"]["lon"]
        city_max_temp=city_weather["main"]["temp_max"]
        city_humidity=city_weather["main"]["humidity"]
        city_clouds=city_weather["clouds"]["all"]
        city_wind=city_weather["wind"]["speed"]
        city_country=city_weather["sys"]["country"]
        city_desc=city_weather["weather"][0]["description"]
        #convert the date to iso standard
        city_date=datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        #append the city data to the city data list
        city_data.append({"City":city.title(),
                         "Lat":city_lat,
                         "Lng":city_lng,
                         "Max Temp":city_max_temp,
                         "Humidity": city_humidity,
                         "cloudiness": city_clouds,
                         "wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date,
                         "Current Description":city_desc})
        #if an error occurs skip the city
    except:
        print("City not found. skiping...")
        pass
    #indicate that data loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of set 1 | illoqqortoormiut
# City not found. skiping...
# Processing Record 2 of set 1 | hermanus
# Processing Record 3 of set 1 | hobart
# Processing Record 4 of set 1 | busselton
# Processing Record 5 of set 1 | miraflores
# Processing Record 6 of set 1 | ushuaia
# Processing Record 7 of set 1 | victoria
# Processing Record 8 of set 1 | nanortalik
# Processing Record 9 of set 1 | puerto ayora
# Processing Record 10 of set 1 | narsaq
# Processing Record 11 of set 1 | bredasdorp
# Processing Record 12 of set 1 | zhigansk
# Processing Record 13 of set 1 | jamestown
# Processing Record 14 of set 1 | port alfred
# Processing Record 15 of set 1 | uribia
# Processing Record 16 of set 1 | castro
# Processing Record 17 of set 1 | grand river south east
# City not found. skiping...
# Processing Record 18 of set 1 | thompson
# Processing Record 19 of set 1 | opuwo
# Processing Record 20 of set 1 | weligama
# Processing Record 21 of set 1 | vanavara
# Processing Record 22 of set 1 | college
# Processing Record 23 of set 1 | sabzevar
# Processing Record 24 of set 1 | carutapera
# Processing Record 25 of set 1 | mataura
# Processing Record 26 of set 1 | saleaula
# City not found. skiping...
# Processing Record 27 of set 1 | salaga
# Processing Record 28 of set 1 | rikitea
# Processing Record 29 of set 1 | cape town
# Processing Record 30 of set 1 | ituango
# Processing Record 31 of set 1 | japura
# Processing Record 32 of set 1 | punta arenas
# Processing Record 33 of set 1 | khatanga
# Processing Record 34 of set 1 | umm lajj
# Processing Record 35 of set 1 | hami
# Processing Record 36 of set 1 | amderma
# City not found. skiping...
# Processing Record 37 of set 1 | kapaa
# Processing Record 38 of set 1 | solnechnyy
# Processing Record 39 of set 1 | pangkalanbuun
# Processing Record 40 of set 1 | nipawin
# Processing Record 41 of set 1 | jiuquan
# Processing Record 42 of set 1 | torbay
# Processing Record 43 of set 1 | longyearbyen
# Processing Record 44 of set 1 | luderitz
# Processing Record 45 of set 1 | cherskiy
# Processing Record 46 of set 1 | bluff
# Processing Record 47 of set 1 | boyolangu
# Processing Record 48 of set 1 | ust-nera
# Processing Record 49 of set 1 | soyo
# Processing Record 50 of set 1 | aswan
# Processing Record 1 of set 2 | phonhong
# Processing Record 2 of set 2 | matane
# Processing Record 3 of set 2 | ribeira grande
# Processing Record 4 of set 2 | tiksi
# Processing Record 5 of set 2 | saint-philippe
# Processing Record 6 of set 2 | nikolskoye
# Processing Record 7 of set 2 | albany
# Processing Record 8 of set 2 | mao
# Processing Record 9 of set 2 | port blair
# Processing Record 10 of set 2 | pirganj
# Processing Record 11 of set 2 | belushya guba
# City not found. skiping...
# Processing Record 12 of set 2 | arraial do cabo
# Processing Record 13 of set 2 | guerrero negro
# Processing Record 14 of set 2 | esperance
# Processing Record 15 of set 2 | alofi
# Processing Record 16 of set 2 | muriti
# Processing Record 17 of set 2 | pevek
# Processing Record 18 of set 2 | temaraia
# City not found. skiping...
# Processing Record 19 of set 2 | namatanai
# Processing Record 20 of set 2 | vila velha
# Processing Record 21 of set 2 | carnarvon
# Processing Record 22 of set 2 | lolua
# City not found. skiping...
# Processing Record 23 of set 2 | emilio carranza
# Processing Record 24 of set 2 | bethel
# Processing Record 25 of set 2 | tayu
# Processing Record 26 of set 2 | atuona
# Processing Record 27 of set 2 | bathsheba
# Processing Record 28 of set 2 | new norfolk
# Processing Record 29 of set 2 | uyuni
# Processing Record 30 of set 2 | cayenne
# Processing Record 31 of set 2 | butaritari
# Processing Record 32 of set 2 | tsihombe
# City not found. skiping...
# Processing Record 33 of set 2 | kenai
# Processing Record 34 of set 2 | rio gallegos
# Processing Record 35 of set 2 | copiapo
# Processing Record 36 of set 2 | taolanaro
# City not found. skiping...
# Processing Record 37 of set 2 | eureka
# Processing Record 38 of set 2 | hilo
# Processing Record 39 of set 2 | coihaique
# Processing Record 40 of set 2 | brigantine
# Processing Record 41 of set 2 | vaini
# Processing Record 42 of set 2 | yerani
# City not found. skiping...
# Processing Record 43 of set 2 | kansanshi
# Processing Record 44 of set 2 | airai
# Processing Record 45 of set 2 | hirado
# Processing Record 46 of set 2 | kamenka
# Processing Record 47 of set 2 | tunduru
# City not found. skiping...
# Processing Record 48 of set 2 | mahebourg
# Processing Record 49 of set 2 | biak
# Processing Record 50 of set 2 | lima
# Processing Record 1 of set 3 | ulaanbaatar
# Processing Record 2 of set 3 | clyde river
# Processing Record 3 of set 3 | ducheng
# Processing Record 4 of set 3 | kruisfontein
# Processing Record 5 of set 3 | sorvag
# City not found. skiping...
# Processing Record 6 of set 3 | east london
# Processing Record 7 of set 3 | novoagansk
# Processing Record 8 of set 3 | kambove
# Processing Record 9 of set 3 | usinsk
# Processing Record 10 of set 3 | dikson
# Processing Record 11 of set 3 | paka
# Processing Record 12 of set 3 | tasiilaq
# Processing Record 13 of set 3 | onalaska
# Processing Record 14 of set 3 | verkh-usugli
# Processing Record 15 of set 3 | porto santo
# Processing Record 16 of set 3 | guozhen
# Processing Record 17 of set 3 | high level
# Processing Record 18 of set 3 | upernavik
# Processing Record 19 of set 3 | maymyo
# Processing Record 20 of set 3 | tabriz
# Processing Record 21 of set 3 | winnemucca
# Processing Record 22 of set 3 | bakchar
# Processing Record 23 of set 3 | tuatapere
# Processing Record 24 of set 3 | kavaratti
# Processing Record 25 of set 3 | lorengau
# Processing Record 26 of set 3 | avarua
# Processing Record 27 of set 3 | mentok
# City not found. skiping...
# Processing Record 28 of set 3 | port elizabeth
# Processing Record 29 of set 3 | rabo de peixe
# Processing Record 30 of set 3 | cabo san lucas
# Processing Record 31 of set 3 | saldanha
# Processing Record 32 of set 3 | asau
# Processing Record 33 of set 3 | komsomolskiy
# Processing Record 34 of set 3 | deputatskiy
# Processing Record 35 of set 3 | saskylakh
# Processing Record 36 of set 3 | port lincoln
# Processing Record 37 of set 3 | ponta do sol
# Processing Record 38 of set 3 | matara
# Processing Record 39 of set 3 | chapleau
# Processing Record 40 of set 3 | ngunguru
# Processing Record 41 of set 3 | tilichiki
# Processing Record 42 of set 3 | dehui
# Processing Record 43 of set 3 | vaitupu
# City not found. skiping...
# Processing Record 44 of set 3 | boguchany
# Processing Record 45 of set 3 | itarema
# Processing Record 46 of set 3 | hofn
# Processing Record 47 of set 3 | egvekinot
# Processing Record 48 of set 3 | mayumba
# Processing Record 49 of set 3 | abalak
# Processing Record 50 of set 3 | barrow
# Processing Record 1 of set 4 | katsuura
# Processing Record 2 of set 4 | labuhan
# Processing Record 3 of set 4 | srednekolymsk
# Processing Record 4 of set 4 | caravelas
# Processing Record 5 of set 4 | yellowknife
# Processing Record 6 of set 4 | ambilobe
# Processing Record 7 of set 4 | la sarre
# Processing Record 8 of set 4 | vao
# Processing Record 9 of set 4 | doctor pedro p. pena
# City not found. skiping...
# Processing Record 10 of set 4 | megion
# Processing Record 11 of set 4 | poum
# Processing Record 12 of set 4 | dingle
# Processing Record 13 of set 4 | hithadhoo
# Processing Record 14 of set 4 | sciacca
# Processing Record 15 of set 4 | mar del plata
# Processing Record 16 of set 4 | pisticci
# Processing Record 17 of set 4 | samusu
# City not found. skiping...
# Processing Record 18 of set 4 | kukuna
# Processing Record 19 of set 4 | pirogovo
# Processing Record 20 of set 4 | lagos
# Processing Record 21 of set 4 | perg
# Processing Record 22 of set 4 | syracuse
# Processing Record 23 of set 4 | chuy
# Processing Record 24 of set 4 | eskasem
# City not found. skiping...
# Processing Record 25 of set 4 | kharovsk
# Processing Record 26 of set 4 | mys shmidta
# City not found. skiping...
# Processing Record 27 of set 4 | jardim de piranhas
# Processing Record 28 of set 4 | dwarka
# Processing Record 29 of set 4 | iqaluit
# Processing Record 30 of set 4 | mandalgovi
# Processing Record 31 of set 4 | bucerias
# Processing Record 32 of set 4 | kodiak
# Processing Record 33 of set 4 | norman wells
# Processing Record 34 of set 4 | muisne
# Processing Record 35 of set 4 | bethanien
# Processing Record 36 of set 4 | connersville
# Processing Record 37 of set 4 | mocuba
# Processing Record 38 of set 4 | marystown
# Processing Record 39 of set 4 | palimbang
# Processing Record 40 of set 4 | melfort
# Processing Record 41 of set 4 | nelson bay
# Processing Record 42 of set 4 | sentyabrskiy
# City not found. skiping...
# Processing Record 43 of set 4 | saint pete beach
# Processing Record 44 of set 4 | ilulissat
# Processing Record 45 of set 4 | leh
# Processing Record 46 of set 4 | itoman
# Processing Record 47 of set 4 | sunnyside
# Processing Record 48 of set 4 | chimbote
# Processing Record 49 of set 4 | tamiahua
# Processing Record 50 of set 4 | batemans bay
# Processing Record 1 of set 5 | asfi
# Processing Record 2 of set 5 | vydrino
# Processing Record 3 of set 5 | zhezkazgan
# Processing Record 4 of set 5 | bambous virieux
# Processing Record 5 of set 5 | charlestown
# Processing Record 6 of set 5 | portlethen
# Processing Record 7 of set 5 | linchuan
# City not found. skiping...
# Processing Record 8 of set 5 | fukue
# Processing Record 9 of set 5 | ust-maya
# Processing Record 10 of set 5 | tomatlan
# Processing Record 11 of set 5 | westport
# Processing Record 12 of set 5 | codrington
# Processing Record 13 of set 5 | igrim
# Processing Record 14 of set 5 | bintulu
# Processing Record 15 of set 5 | kamenskoye
# City not found. skiping...
# Processing Record 16 of set 5 | umm durman
# City not found. skiping...
# Processing Record 17 of set 5 | kajaani
# Processing Record 18 of set 5 | faanui
# Processing Record 19 of set 5 | avera
# Processing Record 20 of set 5 | beberibe
# Processing Record 21 of set 5 | saint george
# Processing Record 22 of set 5 | pangody
# Processing Record 23 of set 5 | korla
# Processing Record 24 of set 5 | broome
# Processing Record 25 of set 5 | chilliwack
# Processing Record 26 of set 5 | pemangkat
# Processing Record 27 of set 5 | praia
# Processing Record 28 of set 5 | san cristobal
# Processing Record 29 of set 5 | ancud
# Processing Record 30 of set 5 | kaitangata
# Processing Record 31 of set 5 | tagusao
# Processing Record 32 of set 5 | barbar
# City not found. skiping...
# Processing Record 33 of set 5 | yurya
# City not found. skiping...
# Processing Record 34 of set 5 | lozovik
# Processing Record 35 of set 5 | klaksvik
# Processing Record 36 of set 5 | gouloure
# Processing Record 37 of set 5 | dokka
# Processing Record 38 of set 5 | yar-sale
# Processing Record 39 of set 5 | udachnyy
# Processing Record 40 of set 5 | baringo
# Processing Record 41 of set 5 | maridi
# Processing Record 42 of set 5 | kalofer
# Processing Record 43 of set 5 | mantua
# Processing Record 44 of set 5 | longhua
# Processing Record 45 of set 5 | verkhovazhye
# Processing Record 46 of set 5 | thinadhoo
# Processing Record 47 of set 5 | touros
# Processing Record 48 of set 5 | marcona
# City not found. skiping...
# Processing Record 49 of set 5 | tabou
# Processing Record 50 of set 5 | safford
# Processing Record 1 of set 6 | peniche
# Processing Record 2 of set 6 | port-gentil
# Processing Record 3 of set 6 | altamira
# Processing Record 4 of set 6 | sainte-anne-des-monts
# Processing Record 5 of set 6 | bengkulu
# Processing Record 6 of set 6 | sitka
# Processing Record 7 of set 6 | qaanaaq
# Processing Record 8 of set 6 | coahuayana
# Processing Record 9 of set 6 | loding
# Processing Record 10 of set 6 | ariquemes
# Processing Record 11 of set 6 | makat
# Processing Record 12 of set 6 | palabuhanratu
# City not found. skiping...
# Processing Record 13 of set 6 | meyungs
# City not found. skiping...
# Processing Record 14 of set 6 | bac lieu
# Processing Record 15 of set 6 | woodstock
# Processing Record 16 of set 6 | chama
# Processing Record 17 of set 6 | basco
# Processing Record 18 of set 6 | paita
# Processing Record 19 of set 6 | flinders
# Processing Record 20 of set 6 | mullaitivu
# City not found. skiping...
# Processing Record 21 of set 6 | neuquen
# Processing Record 22 of set 6 | puli
# Processing Record 23 of set 6 | payson
# Processing Record 24 of set 6 | turukhansk
# Processing Record 25 of set 6 | madang
# Processing Record 26 of set 6 | selma
# Processing Record 27 of set 6 | bam
# Processing Record 28 of set 6 | key west
# Processing Record 29 of set 6 | beloha
# Processing Record 30 of set 6 | tumannyy
# City not found. skiping...
# Processing Record 31 of set 6 | puerto del rosario
# Processing Record 32 of set 6 | manta
# Processing Record 33 of set 6 | worcester
# Processing Record 34 of set 6 | katherine
# Processing Record 35 of set 6 | priargunsk
# Processing Record 36 of set 6 | bermeo
# Processing Record 37 of set 6 | teul
# City not found. skiping...
# Processing Record 38 of set 6 | yashkul
# Processing Record 39 of set 6 | nizhneyansk
# City not found. skiping...
# Processing Record 40 of set 6 | hamilton
# Processing Record 41 of set 6 | swidnik
# Processing Record 42 of set 6 | atbasar
# Processing Record 43 of set 6 | yeppoon
# Processing Record 44 of set 6 | panjab
# Processing Record 45 of set 6 | olafsvik
# Processing Record 46 of set 6 | lamu
# Processing Record 47 of set 6 | changji
# Processing Record 48 of set 6 | san quintin
# Processing Record 49 of set 6 | knoxville
# Processing Record 50 of set 6 | galveston
# Processing Record 1 of set 7 | el viejo
# Processing Record 2 of set 7 | kodinsk
# Processing Record 3 of set 7 | kichmengskiy gorodok
# Processing Record 4 of set 7 | lianzhou
# Processing Record 5 of set 7 | krasnokholmskiy
# Processing Record 6 of set 7 | pulandian
# Processing Record 7 of set 7 | taguatinga
# Processing Record 8 of set 7 | rundu
# Processing Record 9 of set 7 | talnakh
# Processing Record 10 of set 7 | emirdag
# Processing Record 11 of set 7 | dandong
# Processing Record 12 of set 7 | andijon
# Processing Record 13 of set 7 | sumbe
# Processing Record 14 of set 7 | pandan
# Processing Record 15 of set 7 | cockburn town
# Processing Record 16 of set 7 | fortuna
# Processing Record 17 of set 7 | ahuimanu
# Processing Record 18 of set 7 | lebu
# Processing Record 19 of set 7 | bambanglipuro
# Processing Record 20 of set 7 | maniitsoq
# Processing Record 21 of set 7 | samarai
# Processing Record 22 of set 7 | cagayan de tawi-tawi
# City not found. skiping...
# Processing Record 23 of set 7 | mizoch
# Processing Record 24 of set 7 | souillac
# Processing Record 25 of set 7 | banff
# Processing Record 26 of set 7 | cidreira
# Processing Record 27 of set 7 | berlevag
# Processing Record 28 of set 7 | harper
# Processing Record 29 of set 7 | abrau-dyurso
# Processing Record 30 of set 7 | kargasok
# Processing Record 31 of set 7 | manzhouli
# Processing Record 32 of set 7 | ostrovnoy
# Processing Record 33 of set 7 | havre-saint-pierre
# Processing Record 34 of set 7 | lewistown
# Processing Record 35 of set 7 | omsukchan
# Processing Record 36 of set 7 | salalah
# Processing Record 37 of set 7 | lompoc
# Processing Record 38 of set 7 | acapulco
# Processing Record 39 of set 7 | camapua
# Processing Record 40 of set 7 | phan rang
# City not found. skiping...
# Processing Record 41 of set 7 | nouadhibou
# Processing Record 42 of set 7 | saint-pierre
# Processing Record 43 of set 7 | hermiston
# Processing Record 44 of set 7 | aksarka
# Processing Record 45 of set 7 | carpinteria
# Processing Record 46 of set 7 | quatre cocos
# Processing Record 47 of set 7 | daru
# Processing Record 48 of set 7 | halifax
# Processing Record 49 of set 7 | pyshma
# Processing Record 50 of set 7 | kavieng
# Processing Record 1 of set 8 | huixtepec
# Processing Record 2 of set 8 | severnyy
# Processing Record 3 of set 8 | port hardy
# Processing Record 4 of set 8 | le port
# Processing Record 5 of set 8 | saint-francois
# Processing Record 6 of set 8 | visby
# Processing Record 7 of set 8 | rawannawi
# City not found. skiping...
# Processing Record 8 of set 8 | tuktoyaktuk
# Processing Record 9 of set 8 | mount gambier
# Processing Record 10 of set 8 | sabha
# Processing Record 11 of set 8 | ballina
# Processing Record 12 of set 8 | pyapon
# Processing Record 13 of set 8 | ulladulla
# Processing Record 14 of set 8 | vestbygda
# City not found. skiping...
# Processing Record 15 of set 8 | varzea da palma
# Processing Record 16 of set 8 | khomeyn
# Processing Record 17 of set 8 | richards bay
# Processing Record 18 of set 8 | zaltan
# Processing Record 19 of set 8 | lanxi
# Processing Record 20 of set 8 | sao miguel do araguaia
# Processing Record 21 of set 8 | bila
# Processing Record 22 of set 8 | sinnamary
# Processing Record 23 of set 8 | hasaki
# Processing Record 24 of set 8 | koslan
# Processing Record 25 of set 8 | nioro
# Processing Record 26 of set 8 | imbituba
# Processing Record 27 of set 8 | seymchan
# Processing Record 28 of set 8 | fort saint john
# City not found. skiping...
# Processing Record 29 of set 8 | teguise
# Processing Record 30 of set 8 | ayna
# Processing Record 31 of set 8 | pointe michel
# Processing Record 32 of set 8 | hare bay
# Processing Record 33 of set 8 | guiyang
# Processing Record 34 of set 8 | panormos
# Processing Record 35 of set 8 | zhanatas
# City not found. skiping...
# Processing Record 36 of set 8 | provideniya
# Processing Record 37 of set 8 | picos
# Processing Record 38 of set 8 | jackson
# Processing Record 39 of set 8 | makakilo city
# Processing Record 40 of set 8 | gayny
# Processing Record 41 of set 8 | broken hill
# Processing Record 42 of set 8 | vinh
# Processing Record 43 of set 8 | la ronge
# Processing Record 44 of set 8 | stochov
# Processing Record 45 of set 8 | nizwa
# Processing Record 46 of set 8 | vallenar
# Processing Record 47 of set 8 | anadyr
# Processing Record 48 of set 8 | sargatskoye
# Processing Record 49 of set 8 | kabwe
# Processing Record 50 of set 8 | onda
# Processing Record 1 of set 9 | beeskow
# Processing Record 2 of set 9 | kuching
# Processing Record 3 of set 9 | luancheng
# Processing Record 4 of set 9 | berdigestyakh
# Processing Record 5 of set 9 | umm ruwabah
# City not found. skiping...
# Processing Record 6 of set 9 | qui nhon
# Processing Record 7 of set 9 | abu dhabi
# Processing Record 8 of set 9 | ambanja
# Processing Record 9 of set 9 | klooga
# Processing Record 10 of set 9 | teya
# Processing Record 11 of set 9 | grasse
# Processing Record 12 of set 9 | amapa
# Processing Record 13 of set 9 | gomel
# Processing Record 14 of set 9 | attawapiskat
# City not found. skiping...
# Processing Record 15 of set 9 | ulaangom
# Processing Record 16 of set 9 | sorland
# Processing Record 17 of set 9 | areia branca
# Processing Record 18 of set 9 | rantepao
# Processing Record 19 of set 9 | taganak
# Processing Record 20 of set 9 | belaya gora
# Processing Record 21 of set 9 | callaway
# Processing Record 22 of set 9 | barentsburg
# City not found. skiping...
# Processing Record 23 of set 9 | vannes
# Processing Record 24 of set 9 | ust-tsilma
# Processing Record 25 of set 9 | gornopravdinsk
# Processing Record 26 of set 9 | ayodhya
# Processing Record 27 of set 9 | chokurdakh
# Processing Record 28 of set 9 | sidi ali
# Processing Record 29 of set 9 | pisco
# Processing Record 30 of set 9 | bozhou
# Processing Record 31 of set 9 | kurilsk
# Processing Record 32 of set 9 | two rivers
# Processing Record 33 of set 9 | ziarat
# Processing Record 34 of set 9 | daliao
# Processing Record 35 of set 9 | maiduguri
# Processing Record 36 of set 9 | muli
# Processing Record 37 of set 9 | ranong
# Processing Record 38 of set 9 | hambantota
# Processing Record 39 of set 9 | tahta
# Processing Record 40 of set 9 | lulea
# Processing Record 41 of set 9 | diego de almagro
# Processing Record 42 of set 9 | vestmannaeyjar
# Processing Record 43 of set 9 | luan
# Processing Record 44 of set 9 | lasa
# Processing Record 45 of set 9 | belmonte
# Processing Record 46 of set 9 | santa rosa
# Processing Record 47 of set 9 | sao filipe
# Processing Record 48 of set 9 | chitral
# Processing Record 49 of set 9 | nyurba
# Processing Record 50 of set 9 | juazeiro
# Processing Record 1 of set 10 | abu zabad
# Processing Record 2 of set 10 | grajewo
# Processing Record 3 of set 10 | visnes
# Processing Record 4 of set 10 | walvis bay
# Processing Record 5 of set 10 | baruun-urt
# Processing Record 6 of set 10 | salta
# Processing Record 7 of set 10 | namibe
# Processing Record 8 of set 10 | manono
# Processing Record 9 of set 10 | lahad datu
# Processing Record 10 of set 10 | forbes
# Processing Record 11 of set 10 | price
# Processing Record 12 of set 10 | kandrian
# Processing Record 13 of set 10 | luanda
# Processing Record 14 of set 10 | barra do garcas
# Processing Record 15 of set 10 | tahe
# Processing Record 16 of set 10 | great yarmouth
# Processing Record 17 of set 10 | sorong
# Processing Record 18 of set 10 | mackay
# Processing Record 19 of set 10 | caronport
# Processing Record 20 of set 10 | karaton
# Processing Record 21 of set 10 | requena
# Processing Record 22 of set 10 | marsa matruh
# Processing Record 23 of set 10 | herat
# Processing Record 24 of set 10 | nouna
# Processing Record 25 of set 10 | smidovich
# Processing Record 26 of set 10 | laguna
# Processing Record 27 of set 10 | axim
# Processing Record 28 of set 10 | tuy hoa
# Processing Record 29 of set 10 | pasni
# Processing Record 30 of set 10 | elat
# Processing Record 31 of set 10 | halalo
# City not found. skiping...
# Processing Record 32 of set 10 | lazaro cardenas
# Processing Record 33 of set 10 | ometepec
# Processing Record 34 of set 10 | maningrida
# Processing Record 35 of set 10 | shache
# Processing Record 36 of set 10 | sokur
# Processing Record 37 of set 10 | malpe
# Processing Record 38 of set 10 | baiyin
# Processing Record 39 of set 10 | port pirie
# Processing Record 40 of set 10 | waynesville
# Processing Record 41 of set 10 | kalat
# Processing Record 42 of set 10 | tolga
# Processing Record 43 of set 10 | comodoro rivadavia
# Processing Record 44 of set 10 | chiredzi
# Processing Record 45 of set 10 | leningradskiy
# Processing Record 46 of set 10 | hongjiang
# Processing Record 47 of set 10 | kiama
# Processing Record 48 of set 10 | verkhoyansk
# Processing Record 49 of set 10 | goderich
# Processing Record 50 of set 10 | radyvyliv
# Processing Record 1 of set 11 | ukiah
# Processing Record 2 of set 11 | paamiut
# Processing Record 3 of set 11 | lagoa
# Processing Record 4 of set 11 | geraldton
# Processing Record 5 of set 11 | georgetown
# Processing Record 6 of set 11 | isangel
# Processing Record 7 of set 11 | alyangula
# Processing Record 8 of set 11 | san patricio
# Processing Record 9 of set 11 | adrar
# Processing Record 10 of set 11 | zhanaozen
# Processing Record 11 of set 11 | kozulka
# Processing Record 12 of set 11 | okato
# Processing Record 13 of set 11 | baykit
# Processing Record 14 of set 11 | tukrah
# Processing Record 15 of set 11 | mbandaka
# Processing Record 16 of set 11 | worthington
# Processing Record 17 of set 11 | luganville
# Processing Record 18 of set 11 | koumra
# Processing Record 19 of set 11 | kulhudhuffushi
# Processing Record 20 of set 11 | tura
# Processing Record 21 of set 11 | gat
# Processing Record 22 of set 11 | manama
# Processing Record 23 of set 11 | laela
# Processing Record 24 of set 11 | rumphi
# Processing Record 25 of set 11 | araouane
# Processing Record 26 of set 11 | villa sandino
# Processing Record 27 of set 11 | north bend
# Processing Record 28 of set 11 | port hedland
# Processing Record 29 of set 11 | youkounkoun
# Processing Record 30 of set 11 | cazaje
# City not found. skiping...
# Processing Record 31 of set 11 | beringovskiy
# Processing Record 32 of set 11 | shingu
# Processing Record 33 of set 11 | eshowe
# Processing Record 34 of set 11 | petropavlovsk-kamchatskiy
# Processing Record 35 of set 11 | zyryanka
# Processing Record 36 of set 11 | vestmanna
# Processing Record 37 of set 11 | florestopolis
# Processing Record 38 of set 11 | abha
# Processing Record 39 of set 11 | santa maria
# Processing Record 40 of set 11 | harnosand
# Processing Record 41 of set 11 | pokrovskoye
# Processing Record 42 of set 11 | road town
# Processing Record 43 of set 11 | kirovskiy
# Processing Record 44 of set 11 | andenes
# Processing Record 45 of set 11 | pathein
# Processing Record 46 of set 11 | jizan
# Processing Record 47 of set 11 | wonthaggi
# Processing Record 48 of set 11 | pahrump
# Processing Record 49 of set 11 | aflu
# City not found. skiping...
# Processing Record 50 of set 11 | huntsville
# Processing Record 1 of set 12 | port hawkesbury
# Processing Record 2 of set 12 | devils lake
# Processing Record 3 of set 12 | payakumbuh
# Processing Record 4 of set 12 | kwekwe
# Processing Record 5 of set 12 | yanan
# City not found. skiping...
# Processing Record 6 of set 12 | tete
# Processing Record 7 of set 12 | griffith
# Processing Record 8 of set 12 | bonthe
# Processing Record 9 of set 12 | lokosovo
# Processing Record 10 of set 12 | linguere
# Processing Record 11 of set 12 | yelovo
# Processing Record 12 of set 12 | san andres
# Processing Record 13 of set 12 | bilibino
# Processing Record 14 of set 12 | kalmunai
# Processing Record 15 of set 12 | eyl
# Processing Record 16 of set 12 | sibolga
# Processing Record 17 of set 12 | safranbolu
# Processing Record 18 of set 12 | waipawa
# Processing Record 19 of set 12 | ushibuka
# Processing Record 20 of set 12 | haicheng
# Processing Record 21 of set 12 | sumenep
# Processing Record 22 of set 12 | lavrentiya
# Processing Record 23 of set 12 | palatka
# Processing Record 24 of set 12 | hay river
# Processing Record 25 of set 12 | rzeszow
# Processing Record 26 of set 12 | novobirilyussy
# Processing Record 27 of set 12 | longlac
# City not found. skiping...
# Processing Record 28 of set 12 | kizukuri
# Processing Record 29 of set 12 | nuevo progreso
# Processing Record 30 of set 12 | villa juarez
# Processing Record 31 of set 12 | heihe
# Processing Record 32 of set 12 | maykain
# City not found. skiping...
# Processing Record 33 of set 12 | ngukurr
# City not found. skiping...
# Processing Record 34 of set 12 | butembo
# Processing Record 35 of set 12 | sao miguel do guama
# Processing Record 36 of set 12 | ustye
# Processing Record 37 of set 12 | maldonado
# Processing Record 38 of set 12 | hegang
# Processing Record 39 of set 12 | santiago del estero
# Processing Record 40 of set 12 | faya
# Processing Record 41 of set 12 | sungairaya
# Processing Record 42 of set 12 | nakusp
# Processing Record 43 of set 12 | nishihara
# Processing Record 44 of set 12 | anastacio
# Processing Record 45 of set 12 | izhma
# Processing Record 46 of set 12 | murgab
# Processing Record 47 of set 12 | los llanos de aridane
# Processing Record 48 of set 12 | aklavik
# Processing Record 49 of set 12 | gilgit
# Processing Record 50 of set 12 | bratsk
# Processing Record 1 of set 13 | jinji
# Processing Record 2 of set 13 | lucapa
# Processing Record 3 of set 13 | guadalajara
# Processing Record 4 of set 13 | rungata
# City not found. skiping...
# Processing Record 5 of set 13 | shirokiy
# Processing Record 6 of set 13 | homer
# Processing Record 7 of set 13 | west bay
# Processing Record 8 of set 13 | zhangye
# Processing Record 9 of set 13 | bereda
# Processing Record 10 of set 13 | kuche
# City not found. skiping...
# Processing Record 11 of set 13 | buzmeyin
# Processing Record 12 of set 13 | kapoeta
# Processing Record 13 of set 13 | yulara
# Processing Record 14 of set 13 | qaqortoq
# Processing Record 15 of set 13 | alice springs
# Processing Record 16 of set 13 | sortova
# Processing Record 17 of set 13 | kendari
# Processing Record 18 of set 13 | bandarbeyla
# Processing Record 19 of set 13 | fallon
# Processing Record 20 of set 13 | borkenes
# Processing Record 21 of set 13 | yumen
# Processing Record 22 of set 13 | karaul
# City not found. skiping...
# Processing Record 23 of set 13 | moose factory
# Processing Record 24 of set 13 | grants
# Processing Record 25 of set 13 | narayanpet
# Processing Record 26 of set 13 | mutis
# Processing Record 27 of set 13 | okhotsk
# Processing Record 28 of set 13 | ust-ishim
# Processing Record 29 of set 13 | noumea
# Processing Record 30 of set 13 | severo-kurilsk
# Processing Record 31 of set 13 | dumai
# Processing Record 32 of set 13 | ixtapa
# Processing Record 33 of set 13 | verkhnevilyuysk
# Processing Record 34 of set 13 | belyy yar
# Processing Record 35 of set 13 | porbandar
# Processing Record 36 of set 13 | kyle of lochalsh
# City not found. skiping...
# Processing Record 37 of set 13 | kitami
# Processing Record 38 of set 13 | preobrazheniye
# Processing Record 39 of set 13 | erenhot
# Processing Record 40 of set 13 | ughelli
# Processing Record 41 of set 13 | ekibastuz
# Processing Record 42 of set 13 | mogadishu
# Processing Record 43 of set 13 | rach gia
# Processing Record 44 of set 13 | olinda
# Processing Record 45 of set 13 | rio grande
# Processing Record 46 of set 13 | tautira
# Processing Record 47 of set 13 | sai buri
# Processing Record 48 of set 13 | quirinopolis
# Processing Record 49 of set 13 | chapada dos guimaraes
# Processing Record 50 of set 13 | boda
# Processing Record 1 of set 14 | george
# Processing Record 2 of set 14 | candawaga
# City not found. skiping...
# Processing Record 3 of set 14 | muroto
# Processing Record 4 of set 14 | khani
# Processing Record 5 of set 14 | tsogni
# Processing Record 6 of set 14 | raudeberg
# Processing Record 7 of set 14 | guajara-mirim
# City not found. skiping...
# Processing Record 8 of set 14 | iwaki
# Processing Record 9 of set 14 | kwinana
# Processing Record 10 of set 14 | port keats
# Processing Record 11 of set 14 | gardan diwal
# City not found. skiping...
# Processing Record 12 of set 14 | balykshi
# Processing Record 13 of set 14 | dawlatabad
# Processing Record 14 of set 14 | louisbourg
# City not found. skiping...
# Processing Record 15 of set 14 | puerto colombia
# Processing Record 16 of set 14 | narva-joesuu
# Processing Record 17 of set 14 | qabis
# City not found. skiping...
# Processing Record 18 of set 14 | kharabali
# Processing Record 19 of set 14 | huron
# Processing Record 20 of set 14 | coquimbo
# Processing Record 21 of set 14 | cerqueira cesar
# Processing Record 22 of set 14 | roxana
# Processing Record 23 of set 14 | kailua
# Processing Record 24 of set 14 | nalut
# Processing Record 25 of set 14 | veraval
# Processing Record 26 of set 14 | jambi
# Processing Record 27 of set 14 | tatawin
# Processing Record 28 of set 14 | sataua
# City not found. skiping...
# Processing Record 29 of set 14 | sebring
# Processing Record 30 of set 14 | najran
# Processing Record 31 of set 14 | kamaishi
# Processing Record 32 of set 14 | ugoofaaru
# Processing Record 33 of set 14 | lushunkou
# City not found. skiping...
# Processing Record 34 of set 14 | wenling
# Processing Record 35 of set 14 | ilhabela
# Processing Record 36 of set 14 | honiara
# Processing Record 37 of set 14 | kabo
# Processing Record 38 of set 14 | oudtshoorn
# Processing Record 39 of set 14 | grenada
# Processing Record 40 of set 14 | bogorodskoye
# Processing Record 41 of set 14 | bandarban
# Processing Record 42 of set 14 | llanes
# Processing Record 43 of set 14 | suba
# Processing Record 44 of set 14 | senges
# Processing Record 45 of set 14 | metz
# Processing Record 46 of set 14 | tucuma
# Processing Record 47 of set 14 | nyahururu
# Processing Record 48 of set 14 | dataganj
# Processing Record 49 of set 14 | qesarya
# Processing Record 50 of set 14 | lac du bonnet
# Processing Record 1 of set 15 | narnaund
# Processing Record 2 of set 15 | hakkari
# Processing Record 3 of set 15 | kanniyakumari
# Processing Record 4 of set 15 | tessalit
# Processing Record 5 of set 15 | merauke
# Processing Record 6 of set 15 | rorvik
# Processing Record 7 of set 15 | sangar
# Processing Record 8 of set 15 | margate
# Processing Record 9 of set 15 | pingzhuang
# Processing Record 10 of set 15 | vorkuta
# Processing Record 11 of set 15 | odweyne
# Processing Record 12 of set 15 | boromo
# Processing Record 13 of set 15 | bowen
# Processing Record 14 of set 15 | bud
# Processing Record 15 of set 15 | chapais
# Processing Record 16 of set 15 | turayf
# Processing Record 17 of set 15 | batagay
# Processing Record 18 of set 15 | chernyshevskiy
# Processing Record 19 of set 15 | kingsville
# Processing Record 20 of set 15 | winneba
# Processing Record 21 of set 15 | vila franca do campo
# Processing Record 22 of set 15 | sao joao da barra
# Processing Record 23 of set 15 | mtimbira
# Processing Record 24 of set 15 | yavas
# Processing Record 25 of set 15 | novyy buh
# Processing Record 26 of set 15 | huarmey
# Processing Record 27 of set 15 | jiaojiang
# Processing Record 28 of set 15 | sur
# Processing Record 29 of set 15 | alta floresta
# Processing Record 30 of set 15 | anloga
# Processing Record 31 of set 15 | ituni
# City not found. skiping...
# Processing Record 32 of set 15 | vostok
# Processing Record 33 of set 15 | haines junction
# Processing Record 34 of set 15 | swellendam
# Processing Record 35 of set 15 | roma
# Processing Record 36 of set 15 | tambilil
# Processing Record 37 of set 15 | kangaba
# Processing Record 38 of set 15 | ahipara
# Processing Record 39 of set 15 | machali
# Processing Record 40 of set 15 | birobidzhan
# Processing Record 41 of set 15 | antsohihy
# Processing Record 42 of set 15 | kimbe
# Processing Record 43 of set 15 | fort saint james
# Processing Record 44 of set 15 | puruliya
# Processing Record 45 of set 15 | tukums
# Processing Record 46 of set 15 | saint anthony
# Processing Record 47 of set 15 | valparaiso
# Processing Record 48 of set 15 | galatina
# Processing Record 49 of set 15 | jumla
# Processing Record 50 of set 15 | bundaberg
# Processing Record 1 of set 16 | siocon
# Processing Record 2 of set 16 | kaarina
# Processing Record 3 of set 16 | unity
# Processing Record 4 of set 16 | cordoba
# Processing Record 5 of set 16 | dicabisagan
# Processing Record 6 of set 16 | yakeshi
# Processing Record 7 of set 16 | tanem
# Processing Record 8 of set 16 | cuajinicuilapa
# Processing Record 9 of set 16 | wajima
# Processing Record 10 of set 16 | hibbing
# Processing Record 11 of set 16 | papetoai
# Processing Record 12 of set 16 | bahia blanca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a pandas dataframe
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  cloudiness  \
# 0      Hermanus -34.4187   19.2345     57.90        75           3
# 1        Hobart -42.8794  147.3294     70.27        65          75
# 2     Busselton -33.6500  115.3333     53.10        58           3
# 3    Miraflores  19.2167  -98.8083     69.03        56          43
# 4       Ushuaia -54.8000  -68.3000     55.06        44          40
# 5      Victoria  22.2855  114.1577     77.32        91          10
# 6    Nanortalik  60.1432  -45.2371     31.48        79          98
# 7  Puerto Ayora  -0.7393  -90.3518     68.95        78          50
# 8        Narsaq  60.9167  -46.0500     26.82        88         100
# 9    Bredasdorp -34.5322   20.0403     51.12        82           4
#
#    wind Speed Country                 Date Current Description
# 0        4.76      ZA  2021-11-05 23:32:37           clear sky
# 1        4.00      AU  2021-11-05 23:31:50       broken clouds
# 2        7.14      AU  2021-11-05 23:32:38           clear sky
# 3        1.57      MX  2021-11-05 23:32:38    scattered clouds
# 4       18.41      AR  2021-11-05 23:29:46    scattered clouds
# 5        1.01      HK  2021-11-05 23:30:28           clear sky
# 6        3.87      GL  2021-11-05 23:32:39     overcast clouds
# 7        9.10      EC  2021-11-05 23:32:39    scattered clouds
# 8        7.78      GL  2021-11-05 23:32:40     overcast clouds
# 9        4.61      ZA  2021-11-05 23:32:40           clear sky

# %%
new_column_order=["City", "Country","Lat","Lng","Max Temp","Humidity","cloudiness", "wind Speed","Current Description" ]
city_data_df=city_data_df[new_column_order]

# %%
#create output file (CSV)
output_data_file="Weather_Database/WeatherPy_Database.csv"
#export the citydata into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
